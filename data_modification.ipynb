# %%
import pandas as pd

# %%
# !pip install xlrd
data=pd.read_excel("/content/Data Model - Pizza Sales.xlsx")

# %%
data
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
data.drop(["order_time"],axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
import datetime

# %%
data["day_no."]=data["order_date"].dt.day
data["day_name"]=data["order_date"].dt.day_name()
data["month_no."]=data["order_date"].dt.month
data["month_name"]=data["order_date"].dt.month_name()
data["year"]=data["order_date"].dt.year
data.drop(["order_date"],axis=1)
# Out:
#        order_details_id  order_id       pizza_id  quantity  unit_price  \
# 0                     1         1     hawaiian_m         1       13.25
# 1                     2         2  classic_dlx_m         1       16.00
# 2                     3         2  five_cheese_l         1       18.50
# 3                     4         2    ital_supr_l         1       20.75
# 4                     5         2     mexicana_m         1       16.00
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1       16.75
# 48616             48617     21348  four_cheese_l         1       17.95
# 48617             48618     21348   napolitana_s         1       12.00
# 48618             48619     21349     mexicana_l         1       20.25
# 48619             48620     21350      bbq_ckn_s         1       12.75
#
#        total_price pizza_size pizza_category  \
# 0            13.25    Regular        Classic
# ...

# %%
from google.colab import files

# %%
data.to_csv("pizza_data.csv")

# %%
files.download("pizza_data.csv")
